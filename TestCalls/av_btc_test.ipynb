# %%
import os
import requests
import pandas as pd
import json

from dotenv import load_dotenv
load_dotenv()

# %matplotlib inline

# %%
token = os.environ.get('AV_API_KEY')

# %%
def get_crypto_price(symbol, exchange, start_date = None):
    api_key = 'AV_API_KEY'
    api_url = f'https://www.alphavantage.co/query?function=DIGITAL_CURRENCY_DAILY&symbol={symbol}&market={exchange}&apikey={api_key}'
    raw_df = requests.get(api_url).json()
    df = pd.DataFrame(raw_df['Time Series (Digital Currency Daily)']).T
    df = df.rename(columns = {'1a. open (USD)': 'open', '2a. high (USD)': 'high', '3a. low (USD)': 'low', '4a. close (USD)': 'close', '5. volume': 'volume'})
    for i in df.columns:
        df[i] = df[i].astype(float)
    df.index = pd.to_datetime(df.index)
    df = df.iloc[::-1].drop(['1b. open (USD)', '2b. high (USD)', '3b. low (USD)', '4b. close (USD)', '6. market cap (USD)'], axis = 1)
    if start_date:
        df = df[df.index >= start_date]
    return df

btc = get_crypto_price(symbol = 'BTC', exchange = 'USD', start_date = '2018-01-01')
btc
# Out:
#                 open      high       low     close        volume
# 2018-12-31   3803.12   3810.00   3630.33   3702.90  29991.778350
# 2019-01-01   3701.23   3810.16   3642.00   3797.14  23741.687033
# 2019-01-02   3796.45   3882.14   3750.45   3858.56  35156.463369
# 2019-01-03   3857.57   3862.74   3730.00   3766.78  29406.948359
# 2019-01-04   3767.20   3823.64   3703.57   3792.01  29519.554671
# ...              ...       ...       ...       ...           ...
# 2021-09-21  43016.64  43639.00  39600.00  40734.38  84534.080485
# 2021-09-22  40734.09  44000.55  40565.39  43543.61  58349.055420
# 2021-09-23  43546.37  44978.00  43069.09  44865.26  48699.576550
# 2021-09-24  44865.26  45200.00  40675.00  42810.57  84113.426292
# 2021-09-25  42810.58  42950.00  42587.97  42683.09    998.993820
#
# [1000 rows x 5 columns]
